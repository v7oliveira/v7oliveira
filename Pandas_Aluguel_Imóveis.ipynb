# %% [markdown]
# <a href="https://colab.research.google.com/github/v7oliveira/v7oliveira/blob/main/Pandas_Aluguel_Im%C3%B3veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Relatório de Análise 1

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-360ae140-8e3c-4b04-9805-963c7d8f3334" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-360ae140-8e3c-4b04-9805-963c7d8f3334">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aluguel.csv to aluguel (1).csv

# %%
## lendo o arquivo CSV e modificando o separador


dados = pd.read_csv("aluguel.csv", sep= ";")
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
## verificando o tipo de variável

type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# 3    800.0       390.0    20.0
# 4    800.0       230.0     NaN
# 5   1200.0         NaN     NaN
# 6   1300.0       301.0    17.0
# 7  22000.0         NaN     NaN
# 8   1000.0         NaN     NaN
# 9  35000.0     19193.0  3030.0

# %% [markdown]
# # Informações Gerais da base de dados

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ["Tipos de dados"])

# %%
tipos_de_dados.columns.name = 'Variáveis'
tipos_de_dados
# Out:
# Variáveis  Tipos de dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados.shape[1]
# Out:
# 9

# %%
print('A base de dados apresenta {} registros (imóveis) e {} variáveis'.format(dados.shape[0],dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registros (imóveis) e 9 variáveis

# %% [markdown]
# # Tipos de imóveis

# %%
tipo_de_imovel =  dados['Tipo']

# %%
## identificando cada tipo de imóvel sem dados duplicados

tipo_de_imovel.drop_duplicates()
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
tipo_de_imovel.drop_duplicates(inplace = True)
tipo_de_imovel
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %% [markdown]
# # Organizando a visualização dos dados

# %%
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)
tipo_de_imovel
# Out:
#                               Tipo
# 0                        Quitinete
# 1                             Casa
# 2          Conjunto Comercial/Sala
# 3                      Apartamento
# 7               Casa de Condomínio
# 16                  Prédio Inteiro
# 17                            Flat
# 29                      Loja/Salão
# 80         Galpão/Depósito/Armazém
# 83                  Casa Comercial
# 117                   Casa de Vila
# 159                 Terreno Padrão
# 207                    Box/Garagem
# 347                           Loft
# 589    Loja Shopping/ Ct Comercial
# 2157                       Chácara
# 3354         Loteamento/Condomínio
# 4379                         Sítio
# 4721                 Pousada/Chalé
# 6983                        Studio
# 9687                         Hotel
# 23614                    Indústria

# %%
tipo_de_imovel.index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    16,    17,    29,    80,
#                83,   117,   159,   207,   347,   589,  2157,  3354,  4379,
#              4721,  6983,  9687, 23614],
#            dtype='int64')

# %%
tipo_de_imovel.shape[0]
# Out:
# 22

# %%
range(tipo_de_imovel.shape[0])
# Out:
# range(0, 22)

# %%
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])
tipo_de_imovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
tipo_de_imovel.columns.name = 'id'
tipo_de_imovel
# Out:
# id                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %% [markdown]
# ## Imóveis Residenciais

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# 3    800.0       390.0    20.0
# 4    800.0       230.0     NaN
# 5   1200.0         NaN     NaN
# 6   1300.0       301.0    17.0
# 7  22000.0         NaN     NaN
# 8   1000.0         NaN     NaN
# 9  35000.0     19193.0  3030.0

# %%
## filtrar os dados para que apresente Imóveis com a categoria "Residenciais"

list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
## utilizar os dados extraidos e filtrar por tipos que se encaixam em "residencial"

residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa Comercial',
 'Casa de Vila']

residencial
# Out:
# ['Quitinete',
#  'Casa',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Casa Comercial',
#  'Casa de Vila']

# %%
selecao = dados['Tipo'].isin(residencial)

selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
## utilizando o método de seleção de DataFrame

dados_residencial = dados[selecao]
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# 5      1200.0         NaN   NaN
# ...       ...         ...   ...
# 32953   900.0       490.0  48.0
# 32955   800.0       350.0  25.0
# 32956  1800.0       800.0  40.0
# 32957  1400.0       509.0  37.0
# 32958  3000.0       760.0   NaN
#
# [22845 rows x 9 columns]

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Casa Comercial',
#  'Casa de Vila']

# %%
# comparando tamanho dos dados

dados_residencial.shape[0]
# Out:
# 22845

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados_residencial.index = range(dados_residencial.shape[0])

dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22840  Apartamento                 Méier        2      0       0    70
# 22841    Quitinete                Centro        0      0       0    27
# 22842  Apartamento           Jacarepaguá        3      1       2    78
# 22843  Apartamento  São Francisco Xavier        2      1       0    48
# 22844  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# 4      1200.0         NaN   NaN
# ...       ...         ...   ...
# 22840   900.0       490.0  48.0
# 22841   800.0       350.0  25.0
# 22842  1800.0       800.0  40.0
# 22843  1400.0       509.0  37.0
# 22844  3000.0       760.0   NaN
#
# [22845 rows x 9 columns]

# %% [markdown]
# ## Exportando dados para CSV

# %%
dados_residencial.to_csv('dados_residenciais.csv')

# %% [markdown]
# ## Seleções e frequências

# %%
## fazer Upload do arquivo filtrado apenas com dados residenciais

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d3cb893-b67b-4fea-b442-7cd3e5cd191d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d3cb893-b67b-4fea-b442-7cd3e5cd191d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_residenciais.csv to dados_residenciais (2).csv

# %%
dados_2 = pd.read_csv("dados_residenciais.csv", sep = ",")

dados_2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22840       22840  Apartamento                 Méier        2      0       0
# 22841       22841    Quitinete                Centro        0      0       0
# 22842       22842  Apartamento           Jacarepaguá        3      1       2
# 22843       22843  Apartamento  São Francisco Xavier        2      1       0
# 22844       22844  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# 0        40  1700.0       500.0  60.0
# 1       100  7000.0         NaN   NaN
# 2        15   800.0       390.0  20.0
# 3        48   800.0       230.0   NaN
# 4        70  1200.0         NaN   NaN
# ...     ...     ...         ...   ...
# 22840    70   900.0       490.0  48.0
# 22841    27   800.0       350.0  25.0
# 22842    78  1800.0       800.0  40.0
# 22843    48  1400.0       509.0  37.0
# 22844    70  3000.0       760.0   NaN
#
# [22845 rows x 10 columns]

# %%
# Selecionar somente os imóveis classificados como tipo 'Apartamento'

selecao = dados_2['Tipo'] == 'Apartamento'
n1 = dados_2[selecao].shape[0]
n1
# Out:
# 19532

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de condominio' e 'Casa de vila'

selecao = (dados_2['Tipo'] == 'Casa') | (dados_2['Tipo'] == 'Casa de Condomínio') | (dados_2['Tipo'] == 'Casa de Vila')

n2 = dados_2[selecao].shape[0]

n2
# Out:
# 2212

# %%
# Selecionar os imóveis com área entre 60 e 100 metros quadrados, incluindo limites

selecao = (dados_2['Area'] >= 60) & (dados_2['Area'] <=100)
n3 = dados_2[selecao].shape[0]
n3
# Out:
# 8736

# %%
# Selecionar os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00

selecao = (dados_2['Quartos'] >= 4) & (dados_2['Valor'] < 2000)
n4 = dados_2[selecao].shape[0]
n4
# Out:
# 41

# %%
print(" Nº de imóveis classificados como tipo 'Apartamento' -> {}".format(n1))
print(" Nº de imóveis classificados com tipos 'Casa', 'Casa de condominio' e 'Casa de vila' -> {}".format(n2))
print(" Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo limites -> {}".format(n3))
print(" Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> {}".format(n4))
# Out:
#  Nº de imóveis classificados como tipo 'Apartamento' -> 19532
#  Nº de imóveis classificados com tipos 'Casa', 'Casa de condominio' e 'Casa de vila' -> 2212
#  Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo limites -> 8736
#  Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> 41

# %% [markdown]
# ## TRATAMENTO DE DADOS FALTANTES

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# 3    800.0       390.0    20.0
# 4    800.0       230.0     NaN
# 5   1200.0         NaN     NaN
# 6   1300.0       301.0    17.0
# 7  22000.0         NaN     NaN
# 8   1000.0         NaN     NaN
# 9  35000.0     19193.0  3030.0

# %%
## mosntrando as informações dos dados com condição 'NaN'

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# mostrando dados que possuem campos com valor 'NaN'

dados[dados['Valor'].isnull()]
# Out:
#                               Tipo                   Bairro  Quartos  Vagas  \
# 76                     Apartamento          Barra da Tijuca        2      1
# 2186                   Apartamento                     Leme        2      0
# 2456                          Casa             Campo Grande        3      4
# 2646                    Loja/Salão          Barra da Tijuca        0      2
# 2941                   Apartamento                 Botafogo        2      0
# 2973                   Apartamento               Copacabana        2      0
# 6598                    Loja/Salão                  Andaraí        0      0
# 7302                          Casa             Campo Grande        3      2
# 12683                  Apartamento                     Leme        2      0
# 13229                  Apartamento                   Glória        3      0
# 13525                  Apartamento                    Gávea        3      1
# 13579      Conjunto Comercial/Sala                 Botafogo        0      3
# 20948      Conjunto Comercial/Sala  Freguesia (Jacarepaguá)        0      1
# 21822  Loja Shopping/ Ct Comercial          Barra da Tijuca        0      2
# 23056      Conjunto Comercial/Sala                 Botafogo        0      0
# 24805      Conjunto Comercial/Sala                 Botafogo        0      0
# 29166      Conjunto Comercial/Sala                 Botafogo        0      1
#
#        Suites  Area  Valor  Condominio    IPTU
# 76          1    70    NaN       970.0    68.0
# 2186        0    75    NaN       878.0     NaN
# 2456        3   363    NaN         NaN     NaN
# 2646        0    80    NaN         NaN     NaN
# 2941        0    95    NaN      1010.0   170.0
# 2973        0    72    NaN       850.0     NaN
# 6598        0   326    NaN         NaN  1140.0
# 7302        1   100    NaN         NaN     NaN
# 12683       1    75    NaN       878.0     NaN
# 13229       1   135    NaN       910.0   228.0
# 13525       1   105    NaN       880.0   221.0
# 13579       0   200    NaN        10.0     NaN
# 20948       0    24    NaN       500.0    74.0
# 21822       0    77    NaN      3600.0  1390.0
# 23056       0   900    NaN        10.0     NaN
# 24805       0   500    NaN        10.0     NaN
# 29166       0    50    NaN        10.0     NaN

# %%
## Retirarando dados com condição 'NaN'

A = dados.shape[0]
dados.dropna(subset = ['Valor'], inplace = True)
B = dados.shape[0]
A - B
# Out:
# 17

# %% [markdown]
# ## Tratamento de Dados Faltantes (continuação)

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 4089

# %%
selecao = (dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull())

# %%
A = dados.shape[0]
dados = dados[~selecao]
B = dados.shape[0]
A - B
# Out:
# 745

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 3344

# %%
dados = dados.fillna({'Condomimio': 0, 'IPTU': 0})

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 3344

# %%
dados[dados['IPTU'].isnull()].shape[0]
# Out:
# 0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32198 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32198 non-null  object
#  1   Bairro      32198 non-null  object
#  2   Quartos     32198 non-null  int64
#  3   Vagas       32198 non-null  int64
#  4   Suites      32198 non-null  int64
#  5   Area        32198 non-null  int64
#  6   Valor       32198 non-null  float64
#  7   Condominio  28854 non-null  float64
#  8   IPTU        32198 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# ## CRIANDO NOVAS VARIÁVEIS

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head(10)
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                 Quitinete       Copacabana        1      0       0    40
# 1                      Casa  Jardim Botânico        2      0       1   100
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3               Apartamento           Centro        1      0       0    15
# 4               Apartamento     Higienópolis        1      0       0    48
# 6               Apartamento         Cachambi        2      0       0    50
# 7        Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8        Casa de Condomínio            Ramos        2      2       0    65
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 11              Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio    IPTU  Valor Bruto
# 0    1700.0       500.0    60.0       2260.0
# 1    7000.0         NaN     0.0          NaN
# 2    5200.0      4020.0  1111.0      10331.0
# 3     800.0       390.0    20.0       1210.0
# 4     800.0       230.0     0.0       1030.0
# 6    1300.0       301.0    17.0       1618.0
# 7   22000.0         NaN     0.0          NaN
# 8    1000.0         NaN     0.0          NaN
# 9   35000.0     19193.0  3030.0      57223.0
# 11   1500.0       642.0    74.0       2216.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area'].round(2)
dados.head(10)
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                 Quitinete       Copacabana        1      0       0    40
# 1                      Casa  Jardim Botânico        2      0       1   100
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3               Apartamento           Centro        1      0       0    15
# 4               Apartamento     Higienópolis        1      0       0    48
# 6               Apartamento         Cachambi        2      0       0    50
# 7        Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8        Casa de Condomínio            Ramos        2      2       0    65
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 11              Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio    IPTU  Valor Bruto   Valor m2
# 0    1700.0       500.0    60.0       2260.0  42.500000
# 1    7000.0         NaN     0.0          NaN  70.000000
# 2    5200.0      4020.0  1111.0      10331.0  34.666667
# 3     800.0       390.0    20.0       1210.0  53.333333
# 4     800.0       230.0     0.0       1030.0  16.666667
# 6    1300.0       301.0    17.0       1618.0  26.000000
# 7   22000.0         NaN     0.0          NaN  29.333333
# 8    1000.0         NaN     0.0          NaN  15.384615
# 9   35000.0     19193.0  3030.0      57223.0  50.359712
# 11   1500.0       642.0    74.0       2216.0  21.428571

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)
dados.head(10)
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                 Quitinete       Copacabana        1      0       0    40
# 1                      Casa  Jardim Botânico        2      0       1   100
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3               Apartamento           Centro        1      0       0    15
# 4               Apartamento     Higienópolis        1      0       0    48
# 6               Apartamento         Cachambi        2      0       0    50
# 7        Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8        Casa de Condomínio            Ramos        2      2       0    65
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 11              Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio    IPTU  Valor Bruto   Valor m2  Valor Bruto m2
# 0    1700.0       500.0    60.0       2260.0  42.500000           56.50
# 1    7000.0         NaN     0.0          NaN  70.000000             NaN
# 2    5200.0      4020.0  1111.0      10331.0  34.666667           68.87
# 3     800.0       390.0    20.0       1210.0  53.333333           80.67
# 4     800.0       230.0     0.0       1030.0  16.666667           21.46
# 6    1300.0       301.0    17.0       1618.0  26.000000           32.36
# 7   22000.0         NaN     0.0          NaN  29.333333             NaN
# 8    1000.0         NaN     0.0          NaN  15.384615             NaN
# 9   35000.0     19193.0  3030.0      57223.0  50.359712           82.34
# 11   1500.0       642.0    74.0       2216.0  21.428571           31.66

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor Bruto   Valor m2  \
# 0        40  1700.0       500.0    60.0       2260.0  42.500000
# 1       100  7000.0         NaN     0.0          NaN  70.000000
# 2       150  5200.0      4020.0  1111.0      10331.0  34.666667
# 3        15   800.0       390.0    20.0       1210.0  53.333333
# 4        48   800.0       230.0     0.0       1030.0  16.666667
# ...     ...     ...         ...     ...          ...        ...
# 32955    27   800.0       350.0    25.0       1175.0  29.629630
# 32956    78  1800.0       800.0    40.0       2640.0  23.076923
# 32957    48  1400.0       509.0    37.0       1946.0  29.166667
# 32958    70  3000.0       760.0     0.0       3760.0  42.857143
# 32959   250  6500.0      4206.0  1109.0      11815.0  26.000000
#
#        Valor Bruto m2 Tipo Agregado
# 0               56.50   Apartamento
# 1                 NaN          Casa
# 2               68.87   Apartamento
# 3               80.67   Apartamento
# 4               21.46   Apartamento
# ...               ...           ...
# 32955           43.52   Apartamento
# 32956           33.85   Apartamento
# 32957           40.54   Apartamento
# 32958           53.71   Apartamento
# 32959           47.26   Apartamento
#
# [32198 rows x 13 columns]

# %% [markdown]
# ## Excluindo Variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])
dados_aux.head(10)
# Out:
#    Tipo Agregado   Valor m2  Valor Bruto  Valor Bruto m2
# 0    Apartamento  42.500000       2260.0           56.50
# 1           Casa  70.000000          NaN             NaN
# 2    Apartamento  34.666667      10331.0           68.87
# 3    Apartamento  53.333333       1210.0           80.67
# 4    Apartamento  16.666667       1030.0           21.46
# 6    Apartamento  26.000000       1618.0           32.36
# 7           Casa  29.333333          NaN             NaN
# 8           Casa  15.384615          NaN             NaN
# 9    Apartamento  50.359712      57223.0           82.34
# 11   Apartamento  21.428571       2216.0           31.66

# %%
## 1º forma de deletar dados

del dados_aux['Valor Bruto m2']
dados_aux.head(10)
# Out:
#    Tipo Agregado   Valor m2  Valor Bruto
# 0    Apartamento  42.500000       2260.0
# 1           Casa  70.000000          NaN
# 2    Apartamento  34.666667      10331.0
# 3    Apartamento  53.333333       1210.0
# 4    Apartamento  16.666667       1030.0
# 6    Apartamento  26.000000       1618.0
# 7           Casa  29.333333          NaN
# 8           Casa  15.384615          NaN
# 9    Apartamento  50.359712      57223.0
# 11   Apartamento  21.428571       2216.0

# %%
## 2º forma de deletar dados

dados_aux.pop('Valor m2')
# Out:
# 0        42.500000
# 1        70.000000
# 2        34.666667
# 3        53.333333
# 4        16.666667
#            ...
# 32955    29.629630
# 32956    23.076923
# 32957    29.166667
# 32958    42.857143
# 32959    26.000000
# Name: Valor m2, Length: 32198, dtype: float64

# %% [markdown]
# ## CRIANDO AGRUPAMENTOS

# %%
dados.head(10)
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                 Quitinete       Copacabana        1      0       0    40
# 1                      Casa  Jardim Botânico        2      0       1   100
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3               Apartamento           Centro        1      0       0    15
# 4               Apartamento     Higienópolis        1      0       0    48
# 6               Apartamento         Cachambi        2      0       0    50
# 7        Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8        Casa de Condomínio            Ramos        2      2       0    65
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 11              Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio    IPTU  Valor Bruto   Valor m2  Valor Bruto m2  \
# 0    1700.0       500.0    60.0       2260.0  42.500000           56.50
# 1    7000.0         NaN     0.0          NaN  70.000000             NaN
# 2    5200.0      4020.0  1111.0      10331.0  34.666667           68.87
# 3     800.0       390.0    20.0       1210.0  53.333333           80.67
# 4     800.0       230.0     0.0       1030.0  16.666667           21.46
# 6    1300.0       301.0    17.0       1618.0  26.000000           32.36
# 7   22000.0         NaN     0.0          NaN  29.333333             NaN
# 8    1000.0         NaN     0.0          NaN  15.384615             NaN
# 9   35000.0     19193.0  3030.0      57223.0  50.359712           82.34
# 11   1500.0       642.0    74.0       2216.0  21.428571           31.66
#
#    Tipo Agregado
# 0    Apartamento
# 1           Casa
# 2    Apartamento
# 3    Apartamento
# 4    Apartamento
# 6    Apartamento
# 7           Casa
# 8           Casa
# 9    Apartamento
# 11   Apartamento

# %% [markdown]
# ### https://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-stats

# %%
## Média da coluna Valor

dados['Valor'].mean()
# Out:
# 13177.971364681036

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0           Copacabana
# 2      Barra da Tijuca
# 16            Botafogo
# 21              Tijuca
# 25              Leblon
# 27             Ipanema
# 110           Flamengo
# Name: Bairro, dtype: object

# %%
## Criando index para exibir a localização dos dados dentro do Dataframe
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [2, 7, 20, 22, 30, 35, 41, 44, 49, 59, 60, 78, 81, 89, 90, 93, 97, 103, 104, 111, 112, 115, 134, 146, 155, 156, 157, 158, 159, 163, 165, 168, 172, 176, 179, 192, 197, 199, 203, 225, 228, 230, 247, 248, 251, 255, 260, 261, 274, 277, 281, 306, 315, 325, 330, 332, 340, 347, 348, 354, 358, 364, 368, 374, 387, 390, 399, 401, 408, 416, 419, 434, 440, 441, 442, 444, 452, 455, 456, 465, 470, 471, 493, 499, 505, 509, 512, 513, 522, 530, 544, 546, 554, 558, 566, 573, 581, 583, 584, 589, ...], 'Botafogo': [16, 17, 32, 66, 83, 116, 124, 125, 164, 182, 191, 201, 204, 238, 293, 297, 334, 360, 376, 424, 458, 469, 490, 507, 545, 548, 622, 623, 652, 670, 740, 744, 781, 785, 811, 849, 884, 895, 910, 948, 979, 1035, 1083, 1101, 1138, 1148, 1159, 1175, 1192, 1239, 1247, 1266, 1292, 1374, 1381, 1389, 1394, 1403, 1492, 1503, 1508, 1556, 1603, 1621, 1643, 1653, 1668, 1689, 1721, 1749, 1786, 1790, 1791, 1818, 1861, 1906, 1913, 1926, 1939, 1963, 2007, 2036, 2063, 2071, 2094, 2119, 2128, 2154, 2193, 2255, 2284, 2298, 2375, 2396, 2444, 2451, 2473, 2490, 2518, 2544, ...], 'Copacabana': [0, 13, 14, 15, 33, 34, 39, 43, 58, 123, 132, 152, 162, 189, 196, 209, 210, 213, 215, 219, 226, 243, 250, 262, 273, 285, 290, 303, 329, 371, 398, 418, 421, 426, 438, 439, 453, 464, 479, 484, 486, 496, 501, 525, 541, 553, 563, 564, 582, 596, 608, 636, 637, 644, 650, 653, 679, 682, 692, 724, 725, 726, 727, 742, 753, 791, 794, 799, 823, 837, 857, 858, 866, 875, 885, 913, 917, 919, 925, 952, 954, 981, 1000, 1008, 1009, 1014, 1025, 1038, 1041, 1047, 1057, 1074, 1100, 1110, 1115, 1158, 1167, 1203, 1218, 1230, ...], 'Flamengo': [110, 206, 321, 322, 431, 487, 524, 537, 543, 547, 559, 588, 629, 641, 660, 709, 754, 810, 871, 933, 1015, 1046, 1096, 1147, 1199, 1286, 1328, 1336, 1352, 1400, 1416, 1452, 1558, 1629, 1651, 1669, 1686, 1753, 1797, 1836, 1846, 2031, 2088, 2092, 2269, 2279, 2294, 2310, 2324, 2336, 2379, 2408, 2411, 2530, 2552, 2614, 2640, 2643, 2761, 2781, 2826, 2919, 2968, 3025, 3034, 3071, 3286, 3348, 3361, 3416, 3428, 3487, 3513, 3533, 3554, 3577, 3605, 3657, 3707, 3828, 3831, 3845, 3851, 3895, 3943, 3989, 3991, 4015, 4123, 4132, 4138, 4225, 4234, 4366, 4378, 4398, 4459, 4485, 4509, 4539, ...], 'Ipanema': [27, 55, 56, 63, 71, 73, 102, 121, 133, 170, 184, 195, 212, 235, 266, 268, 317, 320, 342, 362, 366, 409, 430, 481, 495, 508, 515, 518, 561, 570, 580, 587, 594, 600, 609, 662, 710, 717, 729, 769, 780, 800, 843, 846, 861, 864, 867, 869, 889, 891, 923, 938, 942, 977, 978, 994, 1010, 1017, 1031, 1042, 1058, 1067, 1071, 1081, 1088, 1094, 1099, 1102, 1106, 1126, 1127, 1134, 1139, 1169, 1173, 1194, 1209, 1212, 1220, 1223, 1224, 1231, 1251, 1290, 1291, 1313, 1330, 1347, 1351, 1358, 1361, 1388, 1393, 1402, 1408, 1430, 1432, 1456, 1459, 1476, ...], 'Leblon': [25, 37, 88, 131, 139, 173, 200, 211, 237, 249, 257, 313, 323, 331, 343, 370, 474, 476, 491, 531, 532, 590, 595, 611, 628, 661, 666, 681, 688, 695, 699, 719, 730, 739, 751, 763, 774, 816, 863, 899, 901, 908, 961, 965, 998, 1037, 1049, 1053, 1061, 1072, 1107, 1129, 1162, 1174, 1235, 1249, 1256, 1257, 1265, 1270, 1300, 1309, 1350, 1366, 1398, 1401, 1420, 1441, 1448, 1473, 1572, 1578, 1589, 1590, 1592, 1598, 1617, 1619, 1634, 1655, 1692, 1709, 1716, 1722, 1773, 1789, 1793, 1804, 1807, 1814, 1839, 1900, 1902, 1908, 1935, 1937, 1989, 1992, 2005, 2046, ...], 'Tijuca': [21, 24, 28, 114, 118, 175, 190, 193, 207, 218, 222, 224, 234, 246, 264, 269, 271, 276, 294, 299, 388, 392, 422, 514, 519, 534, 550, 654, 669, 698, 713, 743, 758, 767, 787, 840, 845, 887, 900, 904, 941, 958, 959, 988, 1020, 1026, 1112, 1119, 1120, 1145, 1164, 1181, 1190, 1197, 1204, 1221, 1263, 1268, 1282, 1304, 1310, 1322, 1327, 1334, 1346, 1384, 1390, 1425, 1453, 1463, 1480, 1483, 1526, 1540, 1549, 1580, 1613, 1657, 1741, 1745, 1751, 1783, 1869, 1881, 1899, 2052, 2099, 2123, 2127, 2134, 2145, 2155, 2190, 2191, 2195, 2226, 2299, 2307, 2349, 2351, ...]}

# %%
for bairro, data in grupo_bairro:
    print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Barra da Tijuca -> 9035.204743465634
# Botafogo -> 19709.716814159292
# Copacabana -> 4514.538436482085
# Flamengo -> 6923.498132004981
# Ipanema -> 10455.031861629495
# Leblon -> 11072.38930774503
# Tijuca -> 2964.5705794947994

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                     Valor  Condominio
# Bairro
# Barra da Tijuca   9035.20     3599.61
# Botafogo         19709.72     3309.87
# Copacabana        4514.54     1212.06
# Flamengo          6923.50     1921.29
# Ipanema          10455.03     2360.60
# Leblon           11072.39     2290.44
# Tijuca            2964.57      854.95

# %% [markdown]
# ## ESTATÍSTICAS DESCRITIVAS

# %%
grupo_bairro["Valor"].describe().round(2)
# Out:
#                   count      mean        std    min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  6198.0   9035.20   30328.23  100.0  2000.0  3500.0   8000.0
# Botafogo         1356.0  19709.72  129879.42  299.0  2500.0  4000.0  11000.0
# Copacabana       3070.0   4514.54    6502.57  100.0  1900.0  3000.0   4900.0
# Flamengo          803.0   6923.50   15848.59  200.0  1900.0  3000.0   5300.0
# Ipanema          2197.0  10455.03   21002.14  100.0  4000.0  6900.0  12000.0
# Leblon           1459.0  11072.39   20830.80  100.0  4500.0  7000.0  11900.0
# Tijuca           1346.0   2964.57    8017.45  320.0  1400.0  1800.0   2500.0
#
#                        max
# Bairro
# Barra da Tijuca   738197.0
# Botafogo         4500000.0
# Copacabana        198000.0
# Flamengo          212544.0
# Ipanema           800000.0
# Leblon            430000.0
# Tijuca            230000.0

# %%
grupo_bairro["Valor"].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo' })
# Out:
#                  Mínimo     Máximo         sum
# Bairro
# Barra da Tijuca   100.0   738197.0  56000199.0
# Botafogo          299.0  4500000.0  26726376.0
# Copacabana        100.0   198000.0  13859633.0
# Flamengo          200.0   212544.0   5559569.0
# Ipanema           100.0   800000.0  22969705.0
# Leblon            100.0   430000.0  16154616.0
# Tijuca            320.0   230000.0   3990312.0

# %%
## utilizando Matplolib

import matplotlib.pyplot as plt
plt.rc('figure', figsize =(20,10))

# %%
# plotando o desvio padrão

fig = grupo_bairro['Valor'].std().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor do desvio padrão', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor do desvio padrão')

# %%
## plotando o valor médio dos imóveis

fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor médio do aluguel por bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor médio do aluguel por bairro')

# %% [markdown]
# ## IDENTIFICANDO E REMOVENDO OUTLIERS

# %%
dados.boxplot(['Valor'])

# %%
dados[dados['Valor'] >= 50000]
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 159             Terreno Padrão  Barra da Tijuca        0      0       0  1110
# 184                Apartamento          Ipanema        4      6       1   700
# 238    Conjunto Comercial/Sala         Botafogo        0      8       0   463
# 376    Conjunto Comercial/Sala         Botafogo        0     28       0  1510
# 408                 Loja/Salão  Barra da Tijuca        0      0       0   210
# ...                        ...              ...      ...    ...     ...   ...
# 32529  Conjunto Comercial/Sala         Botafogo        0     19       0   900
# 32531  Conjunto Comercial/Sala  Barra da Tijuca        0     56       0  1750
# 32656       Casa de Condomínio           Leblon        6      3       6  1206
# 32884  Conjunto Comercial/Sala         Botafogo        0     18       0   958
# 32889  Conjunto Comercial/Sala         Botafogo        0      8       0   467
#
#           Valor  Condominio     IPTU  Valor Bruto    Valor m2  Valor Bruto m2  \
# 159    140000.0         NaN      0.0          NaN  126.126126             NaN
# 184     65000.0      8860.0   5699.0      79559.0   92.857143          113.66
# 238     92600.0     11843.0  14355.0     118798.0  200.000000          256.58
# 376    211400.0     50902.0   8138.0     270440.0  140.000000          179.10
# 408     55000.0         NaN   3000.0          NaN  261.904762             NaN
# ...         ...         ...      ...          ...         ...             ...
# 32529   85500.0     34656.0      0.0     120156.0   95.000000          133.51
# 32531  175000.0     36750.0  78225.0     289975.0  100.000000          165.70
# 32656   55000.0      3200.0   5016.0      63216.0   45.605307           52.42
# 32884   95784.0     29698.0   5509.0     130991.0   99.983299          136.73
# 32889   53730.0     14796.0   2728.0      71254.0  115.053533          152.58
#
#       Tipo Agregado
# 159     Apartamento
# 184     Apartamento
# 238     Apartamento
# 376     Apartamento
# 408     Apartamento
# ...             ...
# 32529   Apartamento
# 32531   Apartamento
# 32656          Casa
# 32884   Apartamento
# 32889   Apartamento
#
# [332 rows x 13 columns]

# %%
valor = dados['Valor']

# %%
## Cálculo primeiro quartil

Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao]

# %%
dados_new.boxplot(['Valor'])

# %%
dados.hist(['Valor'])
dados_new.hist(['Valor'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1dc19a81d0>]],
#       dtype=object)

# %%
dados.boxplot(['Valor'], by = ['Tipo'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
grupo_tipo = dados.groupby('Tipo')

# %%
type(grupo_tipo)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_tipo = dados.groupby('Tipo')['Valor']

# %%
Q1 =  grupo_tipo.quantile(.25)
Q3 =  grupo_tipo.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
Q1
# Out:
# Tipo
# Apartamento                     2400.0
# Box/Garagem                      310.0
# Casa                            5950.0
# Casa Comercial                 10000.0
# Casa de Condomínio              9000.0
# Casa de Vila                    2200.0
# Conjunto Comercial/Sala         1200.0
# Flat                            2500.0
# Galpão/Depósito/Armazém         7725.0
# Hotel                          38000.0
# Loft                            2050.0
# Loja Shopping/ Ct Comercial     1400.0
# Loja/Salão                      3000.0
# Loteamento/Condomínio          28750.0
# Pousada/Chalé                   1480.0
# Prédio Inteiro                 22000.0
# Quitinete                       1100.0
# Studio                          1500.0
# Terreno Padrão                 25000.0
# Name: Valor, dtype: float64

# %%
Q3
# Out:
# Tipo
# Apartamento                      7000.0
# Box/Garagem                       455.0
# Casa                            18000.0
# Casa Comercial                  20500.0
# Casa de Condomínio              20000.0
# Casa de Vila                     3990.0
# Conjunto Comercial/Sala          8525.0
# Flat                             6500.0
# Galpão/Depósito/Armazém         31250.0
# Hotel                           38000.0
# Loft                             3429.5
# Loja Shopping/ Ct Comercial      4500.0
# Loja/Salão                      16000.0
# Loteamento/Condomínio           36250.0
# Pousada/Chalé                    1480.0
# Prédio Inteiro                 120000.0
# Quitinete                        1650.0
# Studio                           1500.0
# Terreno Padrão                 140000.0
# Name: Valor, dtype: float64

# %%
IIQ
# Out:
#                              Quartos  Vagas  Suites    Area     Valor  \
# Tipo
# Apartamento                      1.0    1.0     1.0   90.00    4600.0
# Box/Garagem                      0.0    1.0     0.0    2.00     145.0
# Casa                             1.0    3.0     3.5  374.00   12050.0
# Casa Comercial                   1.0    3.0     0.0  228.25   10500.0
# Casa de Condomínio               1.0    2.0     3.0  415.00   11000.0
# Casa de Vila                     1.0    1.0     1.0   62.00    1790.0
# Conjunto Comercial/Sala          0.0    1.0     0.0  109.00    7325.0
# Flat                             1.0    0.0     1.0   30.00    4000.0
# Galpão/Depósito/Armazém          0.0    5.5     0.0  703.25   23525.0
# Hotel                            0.0    0.0     0.0    0.00       0.0
# Loft                             0.0    1.0     1.0   30.75    1379.5
# Loja Shopping/ Ct Comercial      0.0    1.0     0.0   52.50    3100.0
# Loja/Salão                       0.0    1.0     0.0  171.50   13000.0
# Loteamento/Condomínio            0.0    0.0     0.0  322.50    7500.0
# Pousada/Chalé                    0.0    0.0     0.0    0.00       0.0
# Prédio Inteiro                   0.0    9.5     0.0  750.00   98000.0
# Quitinete                        0.0    0.0     0.0    8.00     550.0
# Studio                           0.0    0.0     0.0    0.00       0.0
# Terreno Padrão                   0.0    0.0     0.0  536.00  115000.0
#
#                              Condominio     IPTU  Valor Bruto   Valor m2  \
# Tipo
# Apartamento                     1200.00   448.00      6165.50  21.369818
# Box/Garagem                       50.00     0.00       187.50        NaN
# Casa                             873.50  1299.00     13462.25  21.526268
# Casa Comercial                   550.00  1640.00     17981.00  31.962647
# Casa de Condomínio              1075.00  1974.50     15895.00  13.712952
# Casa de Vila                     289.00   225.00      2480.25  15.572519
# Conjunto Comercial/Sala         2342.00   617.75     11529.00  35.416667
# Flat                            1180.00   300.00      4762.25  46.250000
# Galpão/Depósito/Armazém         1700.00  1455.75     14625.00  26.452793
# Hotel                               NaN     0.00          NaN   0.000000
# Loft                             905.75   281.50      1757.25  38.241597
# Loja Shopping/ Ct Comercial     1350.00   522.00      3800.50  43.691502
# Loja/Salão                      2091.00  1481.25     14559.00  58.455882
# Loteamento/Condomínio               NaN  2127.50          NaN        NaN
# Pousada/Chalé                      0.00     0.00         0.00   0.000000
# Prédio Inteiro                 97667.00  5508.25    669012.00  46.405378
# Quitinete                        150.50    55.00       631.50  17.142857
# Studio                             0.00     0.00         0.00   0.000000
# Terreno Padrão                      NaN  2756.00          NaN  96.514076
#
#                              Valor Bruto m2
# Tipo
# Apartamento                         26.7075
# Box/Garagem                             NaN
# Casa                                24.8100
# Casa Comercial                      84.2400
# Casa de Condomínio                  21.1500
# Casa de Vila                        14.2400
# Conjunto Comercial/Sala             46.5900
# Flat                                56.7425
# Galpão/Depósito/Armazém              7.0900
# Hotel                                   NaN
# Loft                                33.4300
# Loja Shopping/ Ct Comercial         64.6900
# Loja/Salão                          60.4900
# Loteamento/Condomínio                   NaN
# Pousada/Chalé                        0.0000
# Prédio Inteiro                      40.8450
# Quitinete                           19.3050
# Studio                               0.0000
# Terreno Padrão                          NaN

# %%
limite_inferior
# Out:
#                              Quartos  Vagas  Suites      Area      Valor  \
# Tipo
# Apartamento                      0.5  -0.50   -1.50   -60.000   -4500.00
# Box/Garagem                      0.0  -1.50    0.00    -3.000      92.50
# Casa                             2.5  -3.50   -4.75  -335.000  -12125.00
# Casa Comercial                  -1.5  -4.50    0.00  -142.375   -5750.00
# Casa de Condomínio               2.5   0.00   -2.50  -237.500   -7500.00
# Casa de Vila                     0.5  -1.50   -1.50   -23.000    -485.00
# Conjunto Comercial/Sala          0.0  -0.50    0.00  -132.500   -9787.50
# Flat                            -0.5   1.00   -1.50     5.000   -3500.00
# Galpão/Depósito/Armazém          0.0  -8.25    0.00  -752.375  -27562.50
# Hotel                           24.0   0.00   24.00  1100.000   38000.00
# Loft                             1.0  -1.50   -1.50   -10.875     -19.25
# Loja Shopping/ Ct Comercial      0.0  -1.50    0.00   -48.750   -3250.00
# Loja/Salão                       0.0  -1.50    0.00  -208.250  -16500.00
# Loteamento/Condomínio            0.0   0.00    0.00  -322.500   17500.00
# Pousada/Chalé                   23.0   0.00   23.00   862.000    1480.00
# Prédio Inteiro                   0.0 -14.25    0.00  -675.000 -125000.00
# Quitinete                        1.0   0.00    0.00    13.000     275.00
# Studio                           1.0   0.00    0.00    28.000    1500.00
# Terreno Padrão                   0.0   0.00    0.00  -229.000 -147500.00
#
#                              Condominio      IPTU  Valor Bruto    Valor m2  \
# Tipo
# Apartamento                   -1000.000  -625.000    -5753.250   -4.333635
# Box/Garagem                     252.500     0.000      373.750         NaN
# Casa                           -409.000 -1948.500   -11803.125  -10.482337
# Casa Comercial                 -375.000 -2460.000   -20671.500  -10.941101
# Casa de Condomínio             -587.500 -2421.750   -11737.500   -1.382437
# Casa de Vila                   -391.000  -337.500    -1183.125    1.068702
# Conjunto Comercial/Sala       -2763.000  -926.625   -15133.500  -19.791667
# Flat                           -370.000  -330.000    -2905.625  -25.625000
# Galpão/Depósito/Armazém       -1418.500 -2183.625   -15905.500  -23.163231
# Hotel                               NaN  7504.000          NaN   34.545455
# Loft                           -808.625  -397.000      346.875  -17.603992
# Loja Shopping/ Ct Comercial   -1225.000  -589.250    -2593.750  -31.103756
# Loja/Salão                    -2384.250 -2221.875   -17848.500  -46.139706
# Loteamento/Condomínio               NaN  1872.500          NaN         NaN
# Pousada/Chalé                   295.000     0.000     1775.000    1.716937
# Prédio Inteiro              -141850.500 -8262.375  -959218.500  -21.049309
# Quitinete                       153.750   -82.500      626.750   14.285714
# Studio                          498.000   120.000     2118.000   53.571429
# Terreno Padrão                      NaN -4134.000          NaN -115.272589
#
#                              Valor Bruto m2
# Tipo
# Apartamento                         0.92375
# Box/Garagem                             NaN
# Casa                              -12.34000
# Casa Comercial                    -75.60000
# Casa de Condomínio                 -7.56500
# Casa de Vila                        6.19500
# Conjunto Comercial/Sala            -9.41500
# Flat                              -12.42875
# Galpão/Depósito/Armazém            22.23000
# Hotel                                   NaN
# Loft                                9.85750
# Loja Shopping/ Ct Comercial       -29.28500
# Loja/Salão                        -23.09750
# Loteamento/Condomínio                   NaN
# Pousada/Chalé                       2.06000
# Prédio Inteiro                     16.34000
# Quitinete                          27.42750
# Studio                             75.64000
# Terreno Padrão                          NaN

# %%
limite_superior
# Out:
#                              Quartos  Vagas  Suites      Area      Valor  \
# Tipo
# Apartamento                      4.5   3.50    2.50   300.000   13900.00
# Box/Garagem                      0.0   2.50    0.00     5.000     672.50
# Casa                             6.5   8.50    9.25  1161.000   36075.00
# Casa Comercial                   2.5   7.50    0.00   770.625   36250.00
# Casa de Condomínio               6.5   8.00    9.50  1422.500   36500.00
# Casa de Vila                     4.5   2.50    2.50   225.000    6675.00
# Conjunto Comercial/Sala          0.0   3.50    0.00   303.500   19512.50
# Flat                             3.5   1.00    2.50   125.000   12500.00
# Galpão/Depósito/Armazém          0.0  13.75    0.00  2060.625   66537.50
# Hotel                           24.0   0.00   24.00  1100.000   38000.00
# Loft                             1.0   2.50    2.50   112.125    5498.75
# Loja Shopping/ Ct Comercial      0.0   2.50    0.00   161.250    9150.00
# Loja/Salão                       0.0   2.50    0.00   477.750   35500.00
# Loteamento/Condomínio            0.0   0.00    0.00   967.500   47500.00
# Pousada/Chalé                   23.0   0.00   23.00   862.000    1480.00
# Prédio Inteiro                   0.0  23.75    0.00  2325.000  267000.00
# Quitinete                        1.0   0.00    0.00    45.000    2475.00
# Studio                           1.0   0.00    0.00    28.000    1500.00
# Terreno Padrão                   0.0   0.00    0.00  1915.000  312500.00
#
#                              Condominio       IPTU  Valor Bruto    Valor m2  \
# Tipo
# Apartamento                    3800.000   1167.000    18908.750   81.145635
# Box/Garagem                     452.500      0.000     1123.750         NaN
# Casa                           3085.000   3247.500    42045.875   75.622736
# Casa Comercial                 1825.000   4100.000    51252.500  116.909488
# Casa de Condomínio             3712.500   5476.250    51842.500   53.469369
# Casa de Vila                    765.000    562.500     8737.875   63.358779
# Conjunto Comercial/Sala        6605.000   1544.375    30982.500  121.875000
# Flat                           4350.000    870.000    16143.375  159.375000
# Galpão/Depósito/Armazém        5381.500   3639.375    42594.500   82.647939
# Hotel                               NaN   7504.000          NaN   34.545455
# Loft                           2814.375    729.000     7375.875  135.362395
# Loja Shopping/ Ct Comercial    4175.000   1498.750    12608.250  143.662254
# Loja/Salão                     5979.750   3703.125    40387.500  187.683824
# Loteamento/Condomínio               NaN  10382.500          NaN         NaN
# Pousada/Chalé                   295.000      0.000     1775.000    1.716937
# Prédio Inteiro               248817.500  13770.625  1716829.500  164.572203
# Quitinete                       755.750    137.500     3152.750   82.857143
# Studio                          498.000    120.000     2118.000   53.571429
# Terreno Padrão                      NaN   6890.000          NaN  270.783716
#
#                              Valor Bruto m2
# Tipo
# Apartamento                       107.75375
# Box/Garagem                             NaN
# Casa                               86.90000
# Casa Comercial                    261.36000
# Casa de Condomínio                 77.03500
# Casa de Vila                       63.15500
# Conjunto Comercial/Sala           176.94500
# Flat                              214.54125
# Galpão/Depósito/Armazém            50.59000
# Hotel                                   NaN
# Loft                              143.57750
# Loja Shopping/ Ct Comercial       229.47500
# Loja/Salão                        218.86250
# Loteamento/Condomínio                   NaN
# Pousada/Chalé                       2.06000
# Prédio Inteiro                    179.72000
# Quitinete                         104.64750
# Studio                             75.64000
# Terreno Padrão                          NaN

# %%
limite_superior['Apartamento']
# Out:
# 13900.0

# %%
dados_new = pd.DataFrame()
for tipo in grupo_tipo.groups.keys():
    eh_tipo = dados['Tipo'] == tipo
    eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
    selecao = eh_tipo & eh_dentro_limite
    dados_selecao = dados[selecao]
    dados_new = pd.concat([dados_new, dados_selecao])

# %%
dados_new.boxplot(['Valor'], by = ['Tipo'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
